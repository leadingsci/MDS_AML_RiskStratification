# %%
import pandas as pd
import os,sys
from pathlib import Path

# %%
output_dir = "/share/home/wyz/Project/result/2025/202506/20250605_20250520_1_cibersortx_tumor_cell_kmean_5448_MDS_sAML_AML_merge/20250606_21_MDS_sAML_AML_tumor_chisq_cell_kmean_merge"

# %%
## input

# %%
mutation_f  = "/share/home/wyz/Project/result/2025/202506/20250605_20250520_1_cibersortx_tumor_cell_kmean_5448_MDS_sAML_AML_merge/20250606_9_MDS_sAML_AML_tumor_cell_kmean_and_clinical_data_cor_data/20250606_1_stat_df_chisq_results_mutation.xls"

# %%
mutation_df =  pd.read_csv(mutation_f,sep="\t")
mutation_df
# Out:
#                                 p_value  statistic  df
# kmean_k5_mark_vs_ASXL1_mut     0.061469   8.588142 NaN
# kmean_k5_mark_vs_ASXL2_mut     1.000000   1.205619 NaN
# kmean_k5_mark_vs_BCOR_mut      0.001000  31.498001 NaN
# kmean_k5_mark_vs_CBL_mut       1.000000   0.974132 NaN
# kmean_k5_mark_vs_CEBPA_mut     0.000500  40.333370 NaN
# kmean_k5_mark_vs_CREBBP_mut    0.053973  14.412187 NaN
# kmean_k5_mark_vs_CSF3R_mut     0.742629   2.718451 NaN
# kmean_k5_mark_vs_DNMT3A_mut    0.000500  29.511179 NaN
# kmean_k5_mark_vs_EZH2_mut      0.004498  25.738238 NaN
# kmean_k5_mark_vs_FLT3_mut      0.002499  17.972737 NaN
# kmean_k5_mark_vs_FLT3.ITD_mut  0.001999  17.935278 NaN
# kmean_k5_mark_vs_GATA2_mut     0.373813   3.501442 NaN
# kmean_k5_mark_vs_IDH1_mut      0.025987  11.545039 NaN
# kmean_k5_mark_vs_IDH2_mut      0.003998  16.116044 NaN
# kmean_k5_mark_vs_JAK2_mut      0.544228   3.147953 NaN
# kmean_k5_mark_vs_KIT_mut       0.000500  23.253209 NaN
# ...

# %%
merge_df = mutation_df

# %%
# 行索引转为第一列，并命名为 Group
merge_df.reset_index(inplace=True)
merge_df.rename(columns={"index":"Group"},inplace=True)
merge_df
# Out:
#                             Group   p_value  statistic  df
# 0      kmean_k5_mark_vs_ASXL1_mut  0.061469   8.588142 NaN
# 1      kmean_k5_mark_vs_ASXL2_mut  1.000000   1.205619 NaN
# 2       kmean_k5_mark_vs_BCOR_mut  0.001000  31.498001 NaN
# 3        kmean_k5_mark_vs_CBL_mut  1.000000   0.974132 NaN
# 4      kmean_k5_mark_vs_CEBPA_mut  0.000500  40.333370 NaN
# 5     kmean_k5_mark_vs_CREBBP_mut  0.053973  14.412187 NaN
# 6      kmean_k5_mark_vs_CSF3R_mut  0.742629   2.718451 NaN
# 7     kmean_k5_mark_vs_DNMT3A_mut  0.000500  29.511179 NaN
# 8       kmean_k5_mark_vs_EZH2_mut  0.004498  25.738238 NaN
# 9       kmean_k5_mark_vs_FLT3_mut  0.002499  17.972737 NaN
# 10  kmean_k5_mark_vs_FLT3.ITD_mut  0.001999  17.935278 NaN
# 11     kmean_k5_mark_vs_GATA2_mut  0.373813   3.501442 NaN
# 12      kmean_k5_mark_vs_IDH1_mut  0.025987  11.545039 NaN
# 13      kmean_k5_mark_vs_IDH2_mut  0.003998  16.116044 NaN
# 14      kmean_k5_mark_vs_JAK2_mut  0.544228   3.147953 NaN
# ...

# %%
# 根据条件标记新的列
def mark_p_value(row):
    if row['p_value'] <= 0.001:
        return "***"
    elif row['p_value'] <= 0.01:
        return "**"
    elif row['p_value'] <= 0.05:
        return "*"
    else:
        return "NS."
 
merge_df['p_value_mark'] = merge_df.apply(mark_p_value, axis=1)
merge_df
# Out:
#                             Group   p_value  statistic  df p_value_mark
# 0      kmean_k5_mark_vs_ASXL1_mut  0.061469   8.588142 NaN          NS.
# 1      kmean_k5_mark_vs_ASXL2_mut  1.000000   1.205619 NaN          NS.
# 2       kmean_k5_mark_vs_BCOR_mut  0.001000  31.498001 NaN          ***
# 3        kmean_k5_mark_vs_CBL_mut  1.000000   0.974132 NaN          NS.
# 4      kmean_k5_mark_vs_CEBPA_mut  0.000500  40.333370 NaN          ***
# 5     kmean_k5_mark_vs_CREBBP_mut  0.053973  14.412187 NaN          NS.
# 6      kmean_k5_mark_vs_CSF3R_mut  0.742629   2.718451 NaN          NS.
# 7     kmean_k5_mark_vs_DNMT3A_mut  0.000500  29.511179 NaN          ***
# 8       kmean_k5_mark_vs_EZH2_mut  0.004498  25.738238 NaN           **
# 9       kmean_k5_mark_vs_FLT3_mut  0.002499  17.972737 NaN           **
# 10  kmean_k5_mark_vs_FLT3.ITD_mut  0.001999  17.935278 NaN           **
# 11     kmean_k5_mark_vs_GATA2_mut  0.373813   3.501442 NaN          NS.
# ...

# %%
output_f = os.path.join(output_dir, "20250606_21_MDS_sAML_AML_tumor_chisq_cell_kmean_merge_vs_mutation_stat.xls")
merge_df.to_csv(output_f,index = False)
